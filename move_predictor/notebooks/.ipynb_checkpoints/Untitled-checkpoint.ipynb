# %%
import json
import pandas as pd

# %%
with open("../data/processed/moves_with_coordinates.json") as f:
    moves = json.load(f)

df = pd.DataFrame(moves)
df.head()
# Out:
#      area  order                 address  year  month  \
# 0   Växjö     12        Wieselgrensgatan  2025   10.0
# 1   Växjö     11             Långa gatan  2025    9.0
# 2   Växjö     10               Falkgatan  2024   10.0
# 3  Moheda      9  Östra Järnvägsgatan 13  2022   11.0
# 4      Ör      8                    Ör 1  2021   12.0
#
#                        property_type   area_build_era  living_area_m2  \
# 0                              Villa  1930s and 1940s           172.0
# 1  Apartment building (multi-family)            2000s             NaN
# 2                 Villa (built 1946)  1930s and 1940s           225.0
# 3                 Villa (built 1910)  1960s and 1970s            83.0
# 4                              Villa  1950s and 1960s            87.0
#
#    estimated_value_low_kr  estimated_value_high_kr  \
# 0               2300000.0                3600000.0
# 1                     NaN                      NaN
# 2               5100000.0                7800000.0
# ...
